# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Set up Display Setting

# %%
pd.options.display.max_colwidth = 100

# %% [markdown]
# ## Get data
#
# Read the dataset

# %%
movies_df = pd.read_csv('data/extended_info.csv', delimiter=",", encoding='utf-8')

# %% [markdown]
# ## General Information
#
# Get an overview of the data
# Examine random rows of the DataFrame

# %%
movies_df.sample(10)
# Out:
#      original_language                        original_title  \
# 274                 hi                        मैं ऐसा ही हूँ
# 217                 en                        The Front Page
# 627                 en                       Vanishing Point
# 971                 de                             Maskerade
# 227                 en                            Get Carter
# 990                 en  Mr. Blandings Builds His Dream House
# 55                  en             Beyond a Reasonable Doubt
# 922                 en                             King Kong
# 727                 en                   Brewster's Millions
# 1129                en                           Swamp Water
#
#                                                                                                  overview  \
# 274                A mentally challenged man fights his former father-in-law for custody of his daughter.
# 217   A journalist suffering from burn-out wants to finally say goodbye to his office – but his boss d...
# 627   When his wife goes into a troubled labor while he is on the road over 1200 miles away James Kowa...
# 971   After a masked carnival ball, Gerda Harrandt, wife of the surgeon Carl Ludwig Harrandt, allows t...
# 227   Jack Carter, a mob enforcer living in Las Vegas, travels back to his hometown of Seattle for his...
# 990   An advertising executive dreams of getting out of the city and building a perfect home in the co...
# 55    Remake of a 1956 Fritz Lang film in which a novelist's investigation of a dirty district attorne...
# 922   Adventurous filmmaker, Carl Denham, sets out to produce a motion picture unlike anything the wor...
# 727   The first movie adaptation of the famous novel where a young man has to spend a fortune on 60 da...
# 1129  A hunter happens upon a fugitive and his daughter living in a Georgia swamp. He falls in love wi...
#
#       popularity release_date  vote_average  vote_count  \
# 274        2.504   2005-05-06         4.143        14.0
# 217       11.708   1974-11-01         7.322       289.0
# 627        5.414   1997-01-07         5.800        46.0
# 971        0.861   1934-09-27         5.600         9.0
# 227       11.618   2000-10-06         5.131       476.0
# 990        6.186   1948-03-25         7.000       157.0
# 55        10.591   2009-02-05         5.691       262.0
# 922       16.830   1933-03-15         7.629      1259.0
# 727        0.600   1914-04-14         0.000         0.0
# 1129       2.424   1941-11-16         6.235        31.0
#
#                                      movie  year    status
# 274                      Main Aisa Hi Hoon  2005    remake
# 217                         The Front Page  1974    remake
# 627                        Vanishing Point  1997    remake
# 971                              Maskerade  1934  original
# 227                             Get Carter  2000    remake
# 990   Mr. Blandings Builds His Dream House  1948  original
# 55               Beyond a Reasonable Doubt  2009    remake
# 922                              King Kong  1933  original
# 727                    Brewster's Millions  1914  original
# 1129                           Swamp Water  1941  original

# %% [markdown]
# Provides descriptive statistics of the movies_df DataFrame, including both numerical and categorical columns.

# %%
movies_df.describe(include='all')
# Out:
#        original_language       original_title  \
# count               1149                 1149
# unique                30                  859
# top                   en  Brewster's Millions
# freq                 912                    5
# mean                 NaN                  NaN
# std                  NaN                  NaN
# min                  NaN                  NaN
# 25%                  NaN                  NaN
# 50%                  NaN                  NaN
# 75%                  NaN                  NaN
# max                  NaN                  NaN
#
#                                                                                         overview  \
# count                                                                                       1145
# unique                                                                                      1114
# top     An oppressed Mexican peasant village hires seven gunfighters to help defend their homes.
# freq                                                                                           4
# mean                                                                                         NaN
# std                                                                                          NaN
# min                                                                                          NaN
# 25%                                                                                          NaN
# 50%                                                                                          NaN
# 75%                                                                                          NaN
# max                                                                                          NaN
#
#          popularity release_date  vote_average    vote_count  \
# count   1149.000000         1149   1149.000000   1149.000000
# unique          NaN         1083           NaN           NaN
# top             NaN   1960-10-12           NaN           NaN
# freq            NaN            4           NaN           NaN
# mean      11.367768          NaN      6.204219    873.847694
# std       17.888068          NaN      1.495829   1954.895235
# min        0.600000          NaN      0.000000      0.000000
# 25%        2.956000          NaN      5.793000     22.000000
# 50%        7.956000          NaN      6.477000    143.000000
# 75%       13.724000          NaN      7.098000    752.000000
# max      439.410000          NaN     10.000000  19867.000000
#
#                       movie  year  status
# count                  1197  1197    1197
# unique                  874   111       2
# top     Brewster's Millions  2006  remake
# freq                      5    33     668
# mean                    NaN   NaN     NaN
# std                     NaN   NaN     NaN
# min                     NaN   NaN     NaN
# 25%                     NaN   NaN     NaN
# 50%                     NaN   NaN     NaN
# 75%                     NaN   NaN     NaN
# max                     NaN   NaN     NaN

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# To find out what is the majority language of the movies in the dataset

# %%
language_counts = movies_df['original_language'].value_counts()

# Create the bar plot
plt.bar(language_counts.index, language_counts)

# Add labels and title
plt.xlabel('Original Languages')
plt.ylabel('Counts')
plt.title('Language Counts')


# Display the plot
plt.show()

# %% [markdown]
# To find out what is the top 10 movies that has the highest popularity score in the dataset

# %%
# Sort the DataFrame by popularity in descending order
sorted_df = movies_df.sort_values('popularity', ascending=False)

# Select the top 10 movies
top_10_popularity = sorted_df.head(10)

# Create the bar plot
plt.barh(top_10_popularity['original_title'], top_10_popularity['popularity'])

# Add labels and title
plt.xlabel('Movie Titles')
plt.ylabel('Popularity')
plt.title('Top 10 Popularity by Movie')

# Display the plot
plt.show()

# %% [markdown]
# To find out what is the top 10 movies that get the most votes counts and see if it matches with the popularity score result

# %%
# Sort the DataFrame by vote counts in descending order
sorted_df = movies_df.sort_values('vote_count', ascending=False)

# Select the top 10 movies
top_10_counts = sorted_df.head(10)

# Create the bar plot
plt.barh(top_10_counts['original_title'], top_10_counts['vote_count'])

# Add labels and title
plt.xlabel('Movie Titles')
plt.ylabel('Counts')
plt.title('Top 10 Vote Counts Movies')


# Display the plot
plt.show()

# %% [markdown]
# The vote counts and popularity score does not matches well.
# It could because that people vote for the movies that make them want to comment about it. It could be positive or negative.
# However, the popularity score is based on page views.

# %% [markdown]
# To find out the top 10 movies that is in English in vote average score.
# In order to avoid the effect of outliers,

# %%
# Filter the DataFrame 
language_filter = movies_df['original_language'] == 'en'
vote_count_filter = movies_df['vote_count'] > 874

# Sort the DataFrame by vote average in descending order
sorted_df = movies_df.loc[language_filter&vote_count_filter].sort_values('vote_average', ascending=False)

# Select the top 10 movies
top_10_vote_average = sorted_df.head(10)

# Create the bar plot
plt.barh(top_10_vote_average['original_title'], top_10_vote_average['vote_average'])

# Add labels and title
plt.xlabel('Movie Titles')
plt.ylabel('Vote Average')
plt.title('Top 10 Vote Average Movies')

# Display the plot
plt.show()
